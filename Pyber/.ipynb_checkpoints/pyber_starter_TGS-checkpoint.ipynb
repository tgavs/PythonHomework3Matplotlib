# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data

df_city=pd.read_csv(city_data_to_load)
df_ride=pd.read_csv(ride_data_to_load)


# Combine the data into a single dataset



# Display the data table for preview

# %%
df_city.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
df_ride.head()
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344

# %%
df_all=df_ride.merge(df_city,how='outer',on='city')

# %%
df_all.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2  Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3  Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4  Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
#
#    driver_count   type
# 0             5  Urban
# 1             5  Urban
# 2             5  Urban
# 3             5  Urban
# 4             5  Urban

# %%
df_all.shape
# Out:
# (2375, 6)

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
df_all.type.unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
# Obtain the x and y coordinates for each of the three city types

urban=df_all.loc[df_all['type']=='Urban']
suburban=df_all.loc[df_all['type']=='Suburban']
rural=df_all.loc[df_all['type']=='Rural']

# %%
# Build the scatter plots for each city types

urbanplot=plt.scatter(urban.groupby(['city']).ride_id.count(),urban.groupby(['city']).fare.mean(),
           marker='o',color='red',s=urban.groupby(['city']).driver_count.sum(),label='Urban',alpha=.2)

suburbanplot=plt.scatter(suburban.groupby(['city']).ride_id.count(),suburban.groupby(['city']).fare.mean(),
           marker='o',color='blue',s=suburban.groupby(['city']).driver_count.sum(),label='Suburban',alpha=.2)

ruralplot=plt.scatter(rural.groupby(['city']).ride_id.count(),rural.groupby(['city']).fare.mean(),
           marker='o',color='yellow',s=rural.groupby(['city']).driver_count.sum(),label='Rural',alpha=.2)


# Incorporate the other graph properties

plt.title('Pyber Ride Sharing Data 2016')

plt.xlabel('Total Number of Rides per city')

plt.ylabel('Average Fare ($)')

# Create a legend

lgnd = plt.legend(fontsize="small", mode="Expanded", 
                  numpoints=1, scatterpoints=1, 
                  loc="best", title="City Types", 
                  labelspacing=0.5)
lgnd.legendHandles[0]._sizes = [30]
lgnd.legendHandles[1]._sizes = [30]
lgnd.legendHandles[2]._sizes = [30]


# Incorporate a text label regarding circle size

plt.annotate('Note: \nCircle Size correlates with driver count per city',xy=(50,30),xytext=(42,35),annotation_clip=False)

# Save Figure
plt.show()

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
#preview the original data frame
df_all.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2  Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3  Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4  Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
#
#    driver_count   type
# 0             5  Urban
# 1             5  Urban
# 2             5  Urban
# 3             5  Urban
# 4             5  Urban

# %%
#visualize all the city types

df_all.type.unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
#assign the city types as labels

labels=df_all.type.unique()

# %%
#calculate the % of fares for each city type

sizes_fares=[df_all.fare[df_all['type']==x].sum()/df_all.fare.sum()for x in labels]

# %%
sizes_fares
# Out:
# [0.6272463496228436, 0.3046387206273222, 0.0681149297498341]

# %%
# Build Pie Chart

explode = (0.02,0.02,0.02)

fares_pie=plt.pie(x= sizes_fares,labels=labels,autopct='%1.1f%%',startangle=90, pctdistance=0.85,explode = explode)


#draw center circle to create donut chart (this is not necesary but I think it looks cleaner)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Equals the axis to ensure a circular figure

plt.tight_layout()
plt.axis('equal')

plt.show()
# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
#preview the original data frame
df_all.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2  Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3  Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4  Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
#
#    driver_count   type
# 0             5  Urban
# 1             5  Urban
# 2             5  Urban
# 3             5  Urban
# 4             5  Urban

# %%
#visualize all the city types

df_all.type.unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
#assign the city types as labels

labels=df_all.type.unique()

# %%
#calculate the % of rides for each city type

sizes_rides=[df_all.ride_id[df_all['type']==x].nunique()/df_all.ride_id.count()for x in labels]

# %%
sizes_rides
# Out:
# [0.6842105263157895, 0.2631578947368421, 0.05263157894736842]

# %%
# Build Pie Chart

explode = (0.02,0.02,0.02)

rides_pie=plt.pie(x= sizes_rides,labels=labels,autopct='%1.1f%%',startangle=90, pctdistance=0.85,explode = explode)


#draw center circle to create donut chart (this is not necesary but I think it looks cleaner)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Equals the axis to ensure a circular figure

plt.tight_layout()
plt.axis('equal')

plt.show()
# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
#preview the original data frame
df_all.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2  Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3  Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4  Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
#
#    driver_count   type
# 0             5  Urban
# 1             5  Urban
# 2             5  Urban
# 3             5  Urban
# 4             5  Urban

# %%
#visualize all the city types

df_all.type.unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
#assign the city types as labels

labels=df_all.type.unique()

# %%
#group the data by type and city to get the drivers count by city
driver_count_df=pd.DataFrame(df_all[['city','driver_count','type']].groupby(['type','city']).first())

#reset index to access the columns with comprenhension list
dc_df=driver_count_df.reset_index()

dc_df.head()
# Out:
#     type            city  driver_count
# 0  Rural    Bradshawfurt             7
# 1  Rural       Garzaport             7
# 2  Rural  Harringtonfort             4
# 3  Rural     Jessicaport             1
# 4  Rural      Lake Jamie             4

# %%
#calculate the % of drivers for each city type
sizes_drivers=[dc_df[dc_df['type']==x].driver_count.sum()/dc_df.driver_count.sum() for x in labels]

# %%
sizes_drivers
# Out:
# [0.8089471913891692, 0.16481668348469558, 0.026236125126135216]

# %%
# Build Pie Chart

explode = (0.02,0.02,0.02)

drivers_pie=plt.pie(x= sizes_drivers,labels=labels,autopct='%1.1f%%',startangle=90, pctdistance=0.85,explode = explode)


#draw center circle to create donut chart (this is not necesary but I think it looks cleaner)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Equals the axis to ensure a circular figure

plt.tight_layout()
plt.axis('equal')

plt.show()
# Save Figure

# %%
# Show Figure
plt.show()
